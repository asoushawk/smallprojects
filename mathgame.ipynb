# %% [markdown]
# <a href="https://colab.research.google.com/github/asoushawk/smallprojects/blob/main/mathgame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import randint
import time
import signal
print("Addition Game")
global result
global p
global left1
global left2
p = 1
a = 0
amount1 = 5
amount2 = 5
number = 5
player1numbers = []
player2numbers = []

for _ in range(number):
    randomnumber = randint(10,500)
    player1numbers.append(randomnumber)
   
for _ in range(number):
    randomnumber = randint(10,500)
    player2numbers.append(randomnumber)



left1 = len(player1numbers)
left2 = len(player2numbers)
def gameon():
    

    global left1
    global left2
    global p
    global a
    for _ in range(number):

        print("Turno", p)
        time.sleep(2)
        print("Player 1's turn:")
        time.sleep(2)
        print("Acertos restantes para vencer:", left1)
        time.sleep(2)
        print("Digite dois números cuja soma resulte em:")
        

        
        print("Número 1:")
        number1_input = input()
        print("Número 2:")
        number2_input = input()
        result1 = int(number1_input)
        result2 = int(number2_input)
    
        if result1 + result2 == player1numbers[a]:
         time.sleep(2)
         print(":D")
         time.sleep(2)
         left1 = len(player1numbers)
         pop1 = left1 - 1
         player1numbers.pop(pop1)
         left1 = len(player1numbers)

         print("Acertos restantes para vencer:", left1)
        else:
          time.sleep(2)
          print("Poxa, boa sorte na próxima, vc vai ter que acertar uma vez a mais")
          randomnumber = randint(0,100)
          left1 = len(player1numbers)
          pop1 = left1 - 1
          player1numbers.pop(pop1)
          left1 = len(player1numbers)
          time.sleep(2)
          print("Acertos restantes para vencer:", left1)
        if left1 == 0:
          print("O Jogador número 1 venceu!! :D")
          quit()
          

     #jogador 2

      
        time.sleep(2)
        print("Player 2's turn:")
        time.sleep(2)
        print("Acertos restantes para vencer:", left2)
        time.sleep(2)
        print("Digite dois números cuja soma resulte em:")
        time.sleep(2)
        

        
        print("Número 1:")
        time.sleep(2)
        number1_input = input()
        print("Número 2:")
        number2_input = input()
        result1 = int(number1_input)
        result2 = int(number2_input)
        
        if result1 + result2 == player2numbers[a]:
          time.sleep(2)
          print(":D")
          left2 = len(player2numbers)
          pop2 = left2 - 1
          player2numbers.pop(pop2)
          time.sleep(2)
          print(player2numbers)
          left2 = len(player2numbers)
          print("Acertos restantes para vencer:", left2)
        else:
          time.sleep(2)
          print("Poxa, boa sorte na próxima, vc vai ter que acertar uma vez a mais")
          randomnumber = randint(0,100)
          player2numbers.append(randomnumber)
          left2 = len(player2numbers)
          time.sleep(2)
          print("Acertos restantes para vencer:", left2)     
        if left2 == 0:
          print("Jogador número 2 venceu!")
          quit()
           
        p = p + 1
        a = a +1  
      


def gameon2():
    

    global left1
    global left2
    global p
    global a
    for _ in range(number):

        print("Turno", p)
        time.sleep(2)
        print("Player 1's turn:")
        time.sleep(2)
        print("Acertos restantes para vencer:", left1)
        time.sleep(2)
        print("Digite o resultado da multiplicação:")
        randomnumber1 = randint(1,9)
        randomnumber2 = randint(1,9)
        print(randomnumber1, "*", randomnumber2)
        print("Resultado:")
        number1_input = input()
        result1 = int(number1_input)
    
        if randomnumber1 * randomnumber2 == result1:
         time.sleep(2)
         print(":D")
         time.sleep(2)
         pop1 = left1 - 1
         player1numbers.pop(pop1)
         left1 = len(player1numbers)

         print("Acertos restantes para vencer:", left1)
        else:
          time.sleep(2)
          print("Poxa, boa sorte na próxima, vc vai ter que acertar uma vez a mais")
          randomnumber = randint(0,100)
          player1numbers.append(randomnumber)
          left1 = len(player1numbers)
          time.sleep(2)
          print("Acertos restantes para vencer:", left1)
        if left1 == 0:
          print("O Jogador número 1 venceu!! :D")
          quit()
          

     #jogador 2

      
        time.sleep(2)
        print("Player 2's turn:")
        time.sleep(2)
        print("Acertos restantes para vencer:", left2)
        time.sleep(2)
        print("Digite o resultado da multiplicação:")
        randomnumber1 = randint(1,9)
        randomnumber2 = randint(1,9)
        print(randomnumber1, "*", randomnumber2)
        print("Resultado:")
        number1_input = input()
        result1 = int(number1_input)
    
        if randomnumber1 * randomnumber2 == result1:
         time.sleep(2)
         print(":D")
         time.sleep(2)
         pop2 = left2 - 1
         player2numbers.pop(pop2)
         left2 = len(player2numbers)

         print("Acertos restantes para vencer:", left2)
        else:
          time.sleep(2)
          print("Poxa, boa sorte na próxima, vc vai ter que acertar uma vez a mais")
          randomnumber = randint(0,100)
          player2numbers.append(randomnumber)
          left2 = len(player2numbers)
          time.sleep(2)
          print("Acertos restantes para vencer:", left2)     
        if left2 == 0:
          print("Jogador número 2 venceu!")
          quit()
           
        p = p + 1
        a = a +1  
    


print("Digite 1 para Adição e 2 para Multiplicação:")
choice = input()
if choice == "1":
  gameon()
elif choice == "2":
  gameon2()
# Out:
# Addition Game
# Digite 1 para Adição e 2 para Multiplicação:
# 2
# Turno 1
# Player 1's turn:
# Acertos restantes para vencer: 5
# Digite o resultado da multiplicação:
# 2 * 3
# Resultado:
# 6
# :D
# Acertos restantes para vencer: 4
# Player 2's turn:
# Acertos restantes para vencer: 5
# Digite o resultado da multiplicação:
# 9 * 6
# Resultado:
# 54
# :D
# Acertos restantes para vencer: 4
# Turno 2
# Player 1's turn:
# Acertos restantes para vencer: 4
# Digite o resultado da multiplicação:
# 3 * 8
# Resultado:
# 24
# :D
# Acertos restantes para vencer: 3
# Player 2's turn:
# Acertos restantes para vencer: 4
# Digite o resultado da multiplicação:
# 7 * 8
# Resultado:
# 56
# :D
# Acertos restantes para vencer: 3
# Turno 3
# Player 1's turn:
# Acertos restantes para vencer: 3
# Digite o resultado da multiplicação:
# 5 * 2
# Resultado:
# 10
# :D
# Acertos restantes para vencer: 2
# Player 2's turn:
# Acertos restantes para vencer: 3
# Digite o resultado da multiplicação:
# 4 * 3
# Resultado:
# 12
# :D
# Acertos restantes para vencer: 2
# Turno 4
# Player 1's turn:
# Acertos restantes para vencer: 2
# Digite o resultado da multiplicação:
# 6 * 5
# Resultado:
# 30
# :D
# Acertos restantes para vencer: 1
# Player 2's turn:
# Acertos restantes para vencer: 2
# Digite o resultado da multiplicação:
# 5 * 1
# Resultado:
# 5
# :D
# Acertos restantes para vencer: 1
# Turno 5
# Player 1's turn:
# Acertos restantes para vencer: 1
# Digite o resultado da multiplicação:
# 7 * 1
# Resultado:
# 7
# :D
# Acertos restantes para vencer: 0
# O Jogador número 1 venceu!! :D
# Player 2's turn:
# Acertos restantes para vencer: 1
# Digite o resultado da multiplicação:
# 8 * 2
# Resultado:
